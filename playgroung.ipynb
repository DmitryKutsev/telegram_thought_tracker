# %%
import google.generativeai as genai

from src.config import settings
import json

# %%
genai.configure(api_key=settings.GOOGLE_API_KEY)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Кто такой Миямото Мусаси?")

# %%
response.candidates[0].content.parts[0].text
# Out:
# 'Миямото Мусаси (宮本 武蔵, приблизительно 1584 – 13 июня 1645) — легендарный японский фехтовальщик и стратег, живший в период Эдо. Он считается одним из величайших мастеров меча в истории Японии.  Его слава основана не только на его бесчисленном количестве побед в поединках, но и на его философском подходе к боевым искусствам и жизни в целом.\n\nКлючевые аспекты его жизни и наследия:\n\n* **Мастер меча:** Мусаси был известен своим уникальным стилем боя нитто-рю (двуручный меч), позволявшим ему эффективно сражаться двумя мечами одновременно. Он практически непобедим в дуэлях.\n\n* **Автор "Книги пяти колец" (五輪書, Go Rin No Sho):** Это его знаменитое сочинение, которое рассматривается как классический текст о стратегии, философии и воинском искусстве.  Книга описывает не только технику фехтования, но и более широкие принципы жизни, стратегии в бизнесе и политике. Она продолжает оказывать влияние на людей самых разных профессий.\n\n* **Его жизнь, полная поединков:**  Мусаси начал свою карьеру в раннем возрасте и участвовал в многочисленных дуэлях, одержав победу почти во всех.  Его биография полна драматических событий, путешествий и поединков на жизнь и смерть.\n\n* **Философия:**  В "Книге пяти колец" и своей жизни Мусаси демонстрирует глубокую философию, подчеркивающую важность самопознания, дисциплины, адаптации к обстоятельствам и понимания природы человеческой борьбы.\n\n* **За пределами меча:** В последние годы жизни Мусаси посвятил себя буддизму и искусству,  отказавшись от постоянной практики фехтования.\n\nВ целом, Миямото Мусаси — это не просто мастер меча, но и символ самосовершенствования, стратегического мышления и глубокого понимания человеческой природы.  Его наследие продолжает вдохновлять людей по всему миру.\n'

# %%
# json.loads(response.candidates[0].content.parts[0].text)
